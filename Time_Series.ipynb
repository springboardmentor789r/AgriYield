# %%
import pandas as pd 
import numpy as np
from catboost import CatBoostRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('crop_yield_dataset.csv')

# %%
df=df[df['Crop_Yield']!=0]
df
# Out:
#              Date  Crop_Type Soil_Type  Soil_pH  Temperature   Humidity  \
# 1      2014-01-01       Corn     Loamy     6.50    20.052576  79.947424
# 3      2014-01-01     Barley     Sandy     6.75    19.751848  80.000000
# 4      2014-01-01    Soybean     Peaty     5.50    16.110395  80.000000
# 5      2014-01-01     Cotton     Sandy     6.75    14.826739  80.000000
# 7      2014-01-01     Tomato      Clay     6.25    18.323272  80.000000
# ...           ...        ...       ...      ...          ...        ...
# 36513  2023-12-31     Barley      Clay     6.25    11.617771  80.000000
# 36515  2023-12-31     Cotton      Clay     6.25    19.538555  80.000000
# 36516  2023-12-31  Sugarcane     Peaty     5.50    21.068336  78.931664
# 36518  2023-12-31     Potato     Peaty     5.50    11.079561  80.000000
# 36519  2023-12-31  Sunflower      Clay     6.25    11.455692  80.000000
#
#        Wind_Speed     N     P     K  Crop_Yield  Soil_Quality
# 1        8.591577  84.0  66.0  50.0  104.871310     66.666667
# 3        2.682683  50.0  40.0  30.0   58.939796     35.000000
# 4        7.696070  49.5  45.0  38.5   32.970413     22.166667
# 5       10.366657  55.0  44.0  36.0   29.356115     39.375000
# 7        8.198084  60.0  45.0  40.0   22.221375     42.291667
# ...           ...   ...   ...   ...         ...           ...
# 36513   14.700485  60.0  50.0  40.0   13.069169     43.750000
# 36515    3.666664  66.0  55.0  48.0   73.323885     49.291667
# 36516    8.795036  71.5  54.0  42.0   39.226521     27.916667
# 36518   10.969366  60.5  45.0  31.5    6.067881     22.833333
# 36519    5.394758  60.0  55.0  44.0   11.825986     46.375000
#
# [25495 rows x 12 columns]

# %%
df.drop(columns=['Crop_Type','Soil_Type'],inplace=True)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date')

# %%
df=df.resample('D').mean()
df
# Out:
#              Soil_pH  Temperature   Humidity  Wind_Speed          N  \
# Date
# 2014-01-01  6.250000    17.832341  79.992489    7.649061  61.285714
# 2014-01-02  6.928571    17.403738  79.997477    9.731096  67.285714
# 2014-01-03  6.250000    17.710699  78.611669   12.161914  60.785714
# 2014-01-04  7.125000    17.068594  79.349411    9.476664  69.375000
# 2014-01-05  6.375000    15.439732  80.000000   10.793227  68.062500
# ...              ...          ...        ...         ...        ...
# 2023-12-27  6.406250    18.765488  79.418663   10.391741  63.687500
# 2023-12-28  6.583333    15.818711  79.517023   11.417404  66.000000
# 2023-12-29  6.843750    17.750068  79.094460    9.926405  66.062500
# 2023-12-30  6.555556    15.174002  79.253593    8.844230  64.666667
# 2023-12-31  6.291667    14.639925  79.821944    9.925707  66.000000
#
#                     P          K  Crop_Yield  Soil_Quality
# Date
# 2014-01-01  50.142857  40.142857   52.962570     41.714286
# 2014-01-02  54.500000  43.785714   49.481053     31.964286
# 2014-01-03  49.571429  40.142857   31.582386     40.601190
# 2014-01-04  56.000000  44.937500   35.247034     38.703125
# 2014-01-05  54.562500  43.125000   32.578187     48.994792
# ...               ...        ...         ...           ...
# 2023-12-27  51.937500  41.125000   45.000561     27.786458
# 2023-12-28  54.166667  42.833333   36.566595     41.680556
# 2023-12-29  53.687500  42.375000   42.949637     39.281250
# 2023-12-30  51.944444  41.388889   26.585890     33.787037
# 2023-12-31  53.250000  41.750000   27.374763     34.243056
#
# [3652 rows x 9 columns]

# %%
df = df.sort_index()
df
# Out:
#              Soil_pH  Temperature   Humidity  Wind_Speed          N  \
# Date
# 2014-01-01  6.250000    17.832341  79.992489    7.649061  61.285714
# 2014-01-02  6.928571    17.403738  79.997477    9.731096  67.285714
# 2014-01-03  6.250000    17.710699  78.611669   12.161914  60.785714
# 2014-01-04  7.125000    17.068594  79.349411    9.476664  69.375000
# 2014-01-05  6.375000    15.439732  80.000000   10.793227  68.062500
# ...              ...          ...        ...         ...        ...
# 2023-12-27  6.406250    18.765488  79.418663   10.391741  63.687500
# 2023-12-28  6.583333    15.818711  79.517023   11.417404  66.000000
# 2023-12-29  6.843750    17.750068  79.094460    9.926405  66.062500
# 2023-12-30  6.555556    15.174002  79.253593    8.844230  64.666667
# 2023-12-31  6.291667    14.639925  79.821944    9.925707  66.000000
#
#                     P          K  Crop_Yield  Soil_Quality
# Date
# 2014-01-01  50.142857  40.142857   52.962570     41.714286
# 2014-01-02  54.500000  43.785714   49.481053     31.964286
# 2014-01-03  49.571429  40.142857   31.582386     40.601190
# 2014-01-04  56.000000  44.937500   35.247034     38.703125
# 2014-01-05  54.562500  43.125000   32.578187     48.994792
# ...               ...        ...         ...           ...
# 2023-12-27  51.937500  41.125000   45.000561     27.786458
# 2023-12-28  54.166667  42.833333   36.566595     41.680556
# 2023-12-29  53.687500  42.375000   42.949637     39.281250
# 2023-12-30  51.944444  41.388889   26.585890     33.787037
# 2023-12-31  53.250000  41.750000   27.374763     34.243056
#
# [3652 rows x 9 columns]

# %%
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller, kpss
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plt.figure(figsize=(10, 4))
plt.plot(df['Crop_Yield'])
plt.title("Crop Yield Over Time")
plt.xlabel("Date")
plt.ylabel("Crop Yield")
plt.show()

# %%
series=df['Crop_Yield']

# %%
cols=df.columns.tolist()
n=len(cols)

# %%
df.columns
# Out:
# Index(['Soil_pH', 'Temperature', 'Humidity', 'Wind_Speed', 'N', 'P', 'K',
#        'Crop_Yield', 'Soil_Quality'],
#       dtype='object')

# %%
def test_stationarity(series, col_name):
    print(f"\n--- Stationarity Test for: {col_name} ---\n")
    
    # 1. Plot the series
    plt.figure(figsize=(10,3))
    plt.plot(series)
    plt.title(f"{col_name} Time Series")
    plt.show()
    
    # 2. ACF & PACF plots
    plot_acf(series, lags=30)
    plt.title(f"ACF - {col_name}")
    plt.show()
    
    plot_pacf(series, lags=30)
    plt.title(f"PACF - {col_name}")
    plt.show()
    
    # 3. ADF Test
    adf_result = adfuller(series.dropna())
    print(adf_result)
    print(f"ADF Statistic: {adf_result[0]:.4f}")
    print(f"ADF p-value: {adf_result[1]:.4f}")
    if adf_result[1] < 0.05:
        print("Likely Stationary\n")
    else:
        print("Likely Non-Stationary\n")
    
    # 4. KPSS Test
    kpss_result = kpss(series.dropna(), nlags="auto")
    print(kpss_result)
    print(f"KPSS Statistic: {kpss_result[0]:.4f}")
    print(f"KPSS p-value: {kpss_result[1]:.4f}")
    if kpss_result[1] < 0.05:
        print("Likely Non-Stationary")
    else:
        print("Likely Stationary")

# %%
test_stationarity(df['Crop_Yield'].dropna(), 'Crop_Yield')
# Out:
# --- Stationarity Test for: Crop_Yield ---
# (np.float64(-7.148107107405442), np.float64(3.19331085413878e-10), 14, 3609, {'1%': np.float64(-3.4321632328202996), '5%': np.float64(-2.862341184885642), '10%': np.float64(-2.567196483328331)}, np.float64(26779.234862747773))
# ADF Statistic: -7.1481
# ADF p-value: 0.0000
# Likely Stationary
#
# (np.float64(0.043423677627070334), np.float64(0.1), 35, {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})
# KPSS Statistic: 0.0434
# KPSS p-value: 0.1000
# Likely Stationary
# C:\Users\ujjaw\AppData\Local\Temp\ipykernel_787716\3399664792.py:30: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_result = kpss(series.dropna(), nlags="auto")

# %%
train_size = int(len(df['Crop_Yield']) * 0.9)
train, test = df['Crop_Yield'].iloc[:train_size], df['Crop_Yield'].iloc[train_size:]

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model=SARIMAX(train, order=(1,0,1))

# %%
results=model.fit()

# %%
forecast = results.forecast(steps=20)

# %%
plt.plot(train, label='Train')
plt.plot(test, label='Test')
plt.plot(forecast, label='Forecast', color='red')
plt.legend()
plt.show()

# %%
plt.plot(df['Crop_Yield'], label='Actual')
plt.legend()
plt.show()

# %%
from statsmodels.tsa.arima.model import ARIMA

model = ARIMA(df['Crop_Yield'], order=(1,1,1))
result = model.fit()
result.plot_diagnostics(figsize=(10,6))
plt.show()

# %%
from prophet import Prophet

# %%
df2=df.copy(deep=True)

# %%
df2=df2.reset_index()
df2
# Out:
#            Date   Soil_pH  Temperature   Humidity  Wind_Speed          N  \
# 0    2014-01-01  6.250000    17.832341  79.992489    7.649061  61.285714
# 1    2014-01-02  6.928571    17.403738  79.997477    9.731096  67.285714
# 2    2014-01-03  6.250000    17.710699  78.611669   12.161914  60.785714
# 3    2014-01-04  7.125000    17.068594  79.349411    9.476664  69.375000
# 4    2014-01-05  6.375000    15.439732  80.000000   10.793227  68.062500
# ...         ...       ...          ...        ...         ...        ...
# 3647 2023-12-27  6.406250    18.765488  79.418663   10.391741  63.687500
# 3648 2023-12-28  6.583333    15.818711  79.517023   11.417404  66.000000
# 3649 2023-12-29  6.843750    17.750068  79.094460    9.926405  66.062500
# 3650 2023-12-30  6.555556    15.174002  79.253593    8.844230  64.666667
# 3651 2023-12-31  6.291667    14.639925  79.821944    9.925707  66.000000
#
#               P          K  Crop_Yield  Soil_Quality
# 0     50.142857  40.142857   52.962570     41.714286
# 1     54.500000  43.785714   49.481053     31.964286
# 2     49.571429  40.142857   31.582386     40.601190
# 3     56.000000  44.937500   35.247034     38.703125
# 4     54.562500  43.125000   32.578187     48.994792
# ...         ...        ...         ...           ...
# 3647  51.937500  41.125000   45.000561     27.786458
# 3648  54.166667  42.833333   36.566595     41.680556
# 3649  53.687500  42.375000   42.949637     39.281250
# 3650  51.944444  41.388889   26.585890     33.787037
# 3651  53.250000  41.750000   27.374763     34.243056
#
# [3652 rows x 10 columns]

# %%
df2=df2.rename(columns={"Date":'ds',"Crop_Yield":'y'})

# %%
df2
# Out:
#              ds   Soil_pH  Temperature   Humidity  Wind_Speed          N  \
# 0    2014-01-01  6.250000    17.832341  79.992489    7.649061  61.285714
# 1    2014-01-02  6.928571    17.403738  79.997477    9.731096  67.285714
# 2    2014-01-03  6.250000    17.710699  78.611669   12.161914  60.785714
# 3    2014-01-04  7.125000    17.068594  79.349411    9.476664  69.375000
# 4    2014-01-05  6.375000    15.439732  80.000000   10.793227  68.062500
# ...         ...       ...          ...        ...         ...        ...
# 3647 2023-12-27  6.406250    18.765488  79.418663   10.391741  63.687500
# 3648 2023-12-28  6.583333    15.818711  79.517023   11.417404  66.000000
# 3649 2023-12-29  6.843750    17.750068  79.094460    9.926405  66.062500
# 3650 2023-12-30  6.555556    15.174002  79.253593    8.844230  64.666667
# 3651 2023-12-31  6.291667    14.639925  79.821944    9.925707  66.000000
#
#               P          K          y  Soil_Quality
# 0     50.142857  40.142857  52.962570     41.714286
# 1     54.500000  43.785714  49.481053     31.964286
# 2     49.571429  40.142857  31.582386     40.601190
# 3     56.000000  44.937500  35.247034     38.703125
# 4     54.562500  43.125000  32.578187     48.994792
# ...         ...        ...        ...           ...
# 3647  51.937500  41.125000  45.000561     27.786458
# 3648  54.166667  42.833333  36.566595     41.680556
# 3649  53.687500  42.375000  42.949637     39.281250
# 3650  51.944444  41.388889  26.585890     33.787037
# 3651  53.250000  41.750000  27.374763     34.243056
#
# [3652 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['Soil_pH', 'Temperature', 'Humidity', 'Wind_Speed', 'N', 'P', 'K',
#        'Crop_Yield', 'Soil_Quality'],
#       dtype='object')

# %%
df2 = df2.interpolate()

# %%
df2.isnull().sum()
# Out:
# ds              0
# Soil_pH         0
# Temperature     0
# Humidity        0
# Wind_Speed      0
# N               0
# P               0
# K               0
# y               0
# Soil_Quality    0
# dtype: int64

# %%
train_size = int(len(df2) * 0.8)
train = df2.iloc[:train_size]
test = df2.iloc[train_size:]

# %%
model=Prophet()

# %%
cols=['Soil_pH', 'Temperature', 'Humidity', 'Wind_Speed', 'N', 'P', 'K', 'Soil_Quality']
for c in cols:
    model.add_regressor(c)

# %%
model.fit(train)
# Out:
# 19:16:52 - cmdstanpy - INFO - Chain [1] start processing
# 19:16:52 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = model.make_future_dataframe(periods=len(test), freq='D')
future = future.merge(df2[['ds'] + cols], on='ds', how='left')

# %%
forecast = model.predict(future)
model.plot(forecast)
model.plot_components(forecast)

# %%
pred = forecast[['ds', 'yhat']].iloc[train_size:]

# %%
df2.isnull().sum()
# Out:
# ds              0
# Soil_pH         0
# Temperature     0
# Humidity        0
# Wind_Speed      0
# N               0
# P               0
# K               0
# y               0
# Soil_Quality    0
# dtype: int64

# %%
mae = mean_absolute_error(test['y'], pred['yhat'])
rmse = np.sqrt(mean_squared_error(test['y'], pred['yhat']))
r2 = r2_score(test['y'], pred['yhat'])
mape = np.mean(np.abs((test['y'] - pred['yhat']) / test['y'])) * 100
print(f"MAE: {mae:.2f}")
print(f"R2: {r2:.6f}")
print(f"RMSE: {rmse:.2f}")
print(f"MAPE: {mape:.2f}%")
# Out:
# MAE: 4.73
# R2: 0.741256
# RMSE: 6.19
# MAPE: 34.76%

# %%
import joblib
joblib.dump(model,"Prophet.pkl")
# Out:
# ['Prophet.pkl']
