# %%
import pandas as pd
df=pd.read_csv("/content/crop_yield_dataset.csv")

display(df.head())
# Out:
#          Date Crop_Type Soil_Type  Soil_pH  Temperature   Humidity  \
# 0  01-01-2014      Corn     Loamy     6.50    20.052576  79.947424
# 1  01-01-2014    Barley     Sandy     6.75    19.751848  80.000000
# 2  01-01-2014   Soybean     Peaty     5.50    16.110395  80.000000
# 3  01-01-2014    Cotton     Sandy     6.75    14.826739  80.000000
# 4  01-01-2014    Tomato      Clay     6.25    18.323272  80.000000
#
#    Wind_Speed     N     P     K  Crop_Yield  Soil_Quality
# 0    8.591577  84.0  66.0  50.0  104.871310     66.666667
# 1    2.682683  50.0  40.0  30.0   58.939796     35.000000
# 2    7.696070  49.5  45.0  38.5   32.970413     22.166667
# 3   10.366658  55.0  44.0  36.0   29.356115     39.375000
# 4    8.198084  60.0  45.0  40.0   22.221375     42.291667

# %%
df.shape
# Out:
# (25495, 12)

# %%
df.dtypes
# Out:
# Date             object
# Crop_Type        object
# Soil_Type        object
# Soil_pH         float64
# Temperature     float64
# Humidity        float64
# Wind_Speed      float64
# N               float64
# P               float64
# K               float64
# Crop_Yield      float64
# Soil_Quality    float64
# dtype: object

# %%
df.describe()
# Out:
#            Soil_pH   Temperature      Humidity    Wind_Speed             N  \
# count  25495.00000  25495.000000  25495.000000  25495.000000  25495.000000
# mean       6.60051     21.487087     76.926951     10.002469     66.011649
# std        0.81741      5.499282      3.764779      3.002739     10.906079
# min        5.50000     10.000340     65.004056     -3.388906     45.000000
# 25%        6.25000     17.322668     74.458652      7.966567     58.500000
# 50%        6.50000     21.328478     78.671522      9.968398     65.000000
# 75%        6.75000     25.541348     80.000000     12.028991     71.500000
# max        8.00000     34.995944     80.000000     20.799435     91.000000
#
#                   P             K    Crop_Yield  Soil_Quality
# count  25495.000000  25495.000000  25495.000000  25495.000000
# mean      53.010492     42.017062     38.501749     37.504607
# std        8.815804      8.528551     22.396534     17.705394
# min       36.000000     27.000000      0.001761     13.291667
# 25%       45.000000     35.000000     20.971841     22.500000
# 50%       54.000000     42.000000     37.742150     35.583333
# 75%       60.000000     49.500000     53.209264     49.291667
# max       72.000000     60.000000    136.711982     74.333333

# %%
df.isnull().sum()
# Out:
# Date            0
# Crop_Type       0
# Soil_Type       0
# Soil_pH         0
# Temperature     0
# Humidity        0
# Wind_Speed      0
# N               0
# P               0
# K               0
# Crop_Yield      0
# Soil_Quality    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Crop_Type'].unique()
# Out:
# array(['Corn', 'Barley', 'Soybean', 'Cotton', 'Tomato', 'Potato',
#        'Sunflower', 'Wheat', 'Sugarcane', 'Rice'], dtype=object)

# %%
df['Soil_Type'].nunique()
# Out:
# 5

# %%
df.groupby('Soil_Type')['Crop_Yield'].mean()
# Out:
# Soil_Type
# Clay      41.607553
# Loamy     52.511372
# Peaty     31.327580
# Saline    33.733142
# Sandy     33.407508
# Name: Crop_Yield, dtype: float64

# %%
df['TemperatureHumidity']=df['Temperature']/df['Humidity']

# %%
df.head()
# Out:
#          Date Crop_Type Soil_Type  Soil_pH  Temperature   Humidity  \
# 0  01-01-2014      Corn     Loamy     6.50    20.052576  79.947424
# 1  01-01-2014    Barley     Sandy     6.75    19.751848  80.000000
# 2  01-01-2014   Soybean     Peaty     5.50    16.110395  80.000000
# 3  01-01-2014    Cotton     Sandy     6.75    14.826739  80.000000
# 4  01-01-2014    Tomato      Clay     6.25    18.323272  80.000000
#
#    Wind_Speed     N     P     K  Crop_Yield  Soil_Quality  TemperatureHumidity
# 0    8.591577  84.0  66.0  50.0  104.871310     66.666667             0.250822
# 1    2.682683  50.0  40.0  30.0   58.939796     35.000000             0.246898
# 2    7.696070  49.5  45.0  38.5   32.970413     22.166667             0.201380
# 3   10.366658  55.0  44.0  36.0   29.356115     39.375000             0.185334
# 4    8.198084  60.0  45.0  40.0   22.221375     42.291667             0.229041

# %%
if 'Soil_Type' in df.columns:
    print(df['Soil_Type'].value_counts())

if 'Crop_Type' in df.columns:
    print(df['Crop_Type'].value_counts())
# Out:
# Soil_Type
# Saline    5129
# Clay      5123
# Peaty     5115
# Loamy     5069
# Sandy     5059
# Name: count, dtype: int64
# Crop_Type
# Rice         2569
# Tomato       2566
# Soybean      2565
# Potato       2559
# Sugarcane    2556
# Wheat        2547
# Sunflower    2547
# Cotton       2541
# Corn         2524
# Barley       2521
# Name: count, dtype: int64
